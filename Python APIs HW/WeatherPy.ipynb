# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Homework submitted by: Veena Kottoor

#The code below was given:

# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# The code below was given:

# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 596

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# OpenWeatherMap API Key
api_key = api_key

# Starting URL for Weather Map API Call
# Specify weather and the units
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Initialize the record number and set number
record = 1
sets = 1

print(f"Beginning Data Retrieval")
print(f"-------------------------------")

# Loop through the cities in the list
for city in cities:  
    
    # Try statement to append calls where value is found 
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} of Set {sets} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase record number by one each time
        record = record + 1
        
        # Increase set by one after printing 50 records (set of 50s)
        if record == 51:
            sets = sets + 1
            record = 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # If the value is not found, then move on to the next call
    except:
        print("City not found. Skipping...")
    continue
    
# Print when out of the for loop, and data retrieval is complete
    
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 | San Cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=san cristobal
# Processing Record 2 of Set 1 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=hermanus
# City not found. Skipping...
# Processing Record 3 of Set 1 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=ushuaia
# Processing Record 4 of Set 1 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=barrow
# City not found. Skipping...
# Processing Record 5 of Set 1 | Labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=labuhan
# Processing Record 6 of Set 1 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=cherskiy
# Processing Record 7 of Set 1 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=kodiak
# Processing Record 8 of Set 1 | Grand-Lahou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=grand-lahou
# Processing Record 9 of Set 1 | Cananea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=cananea
# Processing Record 10 of Set 1 | Antofagasta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=antofagasta
# Processing Record 11 of Set 1 | Victor Harbor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=victor harbor
# Processing Record 12 of Set 1 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=bambous virieux
# Processing Record 13 of Set 1 | Monte Santo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=monte santo
# Processing Record 14 of Set 1 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=vaini
# Processing Record 15 of Set 1 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=jamestown
# Processing Record 16 of Set 1 | Tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=tautira
# Processing Record 17 of Set 1 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=yellowknife
# Processing Record 18 of Set 1 | Hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=hofn
# Processing Record 19 of Set 1 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=bredasdorp
# Processing Record 20 of Set 1 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=new norfolk
# Processing Record 21 of Set 1 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=rikitea
# Processing Record 22 of Set 1 | Mocuba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=mocuba
# City not found. Skipping...
# Processing Record 23 of Set 1 | Baherden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=baherden
# Processing Record 24 of Set 1 | Havelock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=havelock
# Processing Record 25 of Set 1 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=upernavik
# Processing Record 26 of Set 1 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=hasaki
# Processing Record 27 of Set 1 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=tuktoyaktuk
# Processing Record 28 of Set 1 | Vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=vostok
# Processing Record 29 of Set 1 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=mahebourg
# Processing Record 30 of Set 1 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=kapaa
# Processing Record 31 of Set 1 | Pampa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=pampa
# City not found. Skipping...
# Processing Record 32 of Set 1 | Victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=victoria
# Processing Record 33 of Set 1 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=ponta do sol
# Processing Record 34 of Set 1 | Dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=dingle
# Processing Record 35 of Set 1 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=busselton
# Processing Record 36 of Set 1 | Kottagudem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=kottagudem
# Processing Record 37 of Set 1 | Tucuman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=tucuman
# Processing Record 38 of Set 1 | Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=vila franca do campo
# City not found. Skipping...
# Processing Record 39 of Set 1 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=albany
# Processing Record 40 of Set 1 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=hilo
# Processing Record 41 of Set 1 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=punta arenas
# Processing Record 42 of Set 1 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=norman wells
# Processing Record 43 of Set 1 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=airai
# Processing Record 44 of Set 1 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=pevek
# Processing Record 45 of Set 1 | Puerto Leguizamo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=puerto leguizamo
# Processing Record 46 of Set 1 | Yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=yumen
# Processing Record 47 of Set 1 | Vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=vestmannaeyjar
# Processing Record 48 of Set 1 | Boguchany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=boguchany
# Processing Record 49 of Set 1 | Sabha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=sabha
# Processing Record 50 of Set 1 | Shawinigan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=shawinigan
# Processing Record 1 of Set 2 | Batagay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=batagay
# Processing Record 2 of Set 2 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=atuona
# Processing Record 3 of Set 2 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=ribeira grande
# Processing Record 4 of Set 2 | Richards Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=richards bay
# Processing Record 5 of Set 2 | Carutapera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=carutapera
# Processing Record 6 of Set 2 | Jalalabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=jalalabad
# Processing Record 7 of Set 2 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=mataura
# Processing Record 8 of Set 2 | Samarkand
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=samarkand
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 9 of Set 2 | Weligama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=weligama
# Processing Record 10 of Set 2 | Chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=chapais
# Processing Record 11 of Set 2 | Guarapari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=guarapari
# Processing Record 12 of Set 2 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=qaanaaq
# Processing Record 13 of Set 2 | Cockburn Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=cockburn town
# Processing Record 14 of Set 2 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=port alfred
# Processing Record 15 of Set 2 | Huangmei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=huangmei
# Processing Record 16 of Set 2 | Hit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=hit
# Processing Record 17 of Set 2 | Krasnoborsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=krasnoborsk
# Processing Record 18 of Set 2 | Omsukchan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=omsukchan
# Processing Record 19 of Set 2 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=ilulissat
# Processing Record 20 of Set 2 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=dikson
# Processing Record 21 of Set 2 | Podgorica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=podgorica
# Processing Record 22 of Set 2 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=longyearbyen
# Processing Record 23 of Set 2 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=puerto ayora
# Processing Record 24 of Set 2 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=tiksi
# City not found. Skipping...
# Processing Record 25 of Set 2 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=esperance
# Processing Record 26 of Set 2 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=georgetown
# Processing Record 27 of Set 2 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=chokurdakh
# Processing Record 28 of Set 2 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=saint-philippe
# Processing Record 29 of Set 2 | Yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=yulara
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 30 of Set 2 | Sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=sorland
# Processing Record 31 of Set 2 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=hithadhoo
# Processing Record 32 of Set 2 | Meiktila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=meiktila
# Processing Record 33 of Set 2 | Vitim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=vitim
# Processing Record 34 of Set 2 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=lebu
# Processing Record 35 of Set 2 | Dukat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=dukat
# Processing Record 36 of Set 2 | Corrales
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=corrales
# Processing Record 37 of Set 2 | Adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=adrar
# Processing Record 38 of Set 2 | Ocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=ocos
# Processing Record 39 of Set 2 | Ergani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=ergani
# Processing Record 40 of Set 2 | Marzuq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=marzuq
# Processing Record 41 of Set 2 | Zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=zhigansk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 2 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=torbay
# Processing Record 43 of Set 2 | Arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=arlit
# Processing Record 44 of Set 2 | Mareeba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=mareeba
# Processing Record 45 of Set 2 | Nadym
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=nadym
# City not found. Skipping...
# Processing Record 46 of Set 2 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=mar del plata
# Processing Record 47 of Set 2 | Almaznyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=almaznyy
# Processing Record 48 of Set 2 | Half Moon Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=half moon bay
# Processing Record 49 of Set 2 | Terney
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=terney
# Processing Record 50 of Set 2 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=hobart
# Processing Record 1 of Set 3 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=luderitz
# Processing Record 2 of Set 3 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=saint george
# City not found. Skipping...
# Processing Record 3 of Set 3 | Myanaung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=myanaung
# Processing Record 4 of Set 3 | Bonthe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=bonthe
# Processing Record 5 of Set 3 | Mattru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=mattru
# Processing Record 6 of Set 3 | Naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=naze
# Processing Record 7 of Set 3 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=castro
# Processing Record 8 of Set 3 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=aklavik
# Processing Record 9 of Set 3 | Davila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=davila
# Processing Record 10 of Set 3 | Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=srednekolymsk
# Processing Record 11 of Set 3 | Buraydah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=buraydah
# Processing Record 12 of Set 3 | Alta Floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=alta floresta
# Processing Record 13 of Set 3 | Reconquista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=reconquista
# Processing Record 14 of Set 3 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=arraial do cabo
# Processing Record 15 of Set 3 | Mgandu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=mgandu
# Processing Record 16 of Set 3 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=avarua
# City not found. Skipping...
# Processing Record 17 of Set 3 | Deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=deputatskiy
# Processing Record 18 of Set 3 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=nikolskoye
# Processing Record 19 of Set 3 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=kavieng
# Processing Record 20 of Set 3 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=provideniya
# Processing Record 21 of Set 3 | Saint-Joseph
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=saint-joseph
# City not found. Skipping...
# Processing Record 22 of Set 3 | Pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=pangnirtung
# Processing Record 23 of Set 3 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=tasiilaq
# Processing Record 24 of Set 3 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=tuatapere
# Processing Record 25 of Set 3 | Celestun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=celestun
# City not found. Skipping...
# Processing Record 26 of Set 3 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=mount gambier
# Processing Record 27 of Set 3 | Kahta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=kahta
# City not found. Skipping...
# Processing Record 28 of Set 3 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=port elizabeth
# Processing Record 29 of Set 3 | Champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=champerico
# Processing Record 30 of Set 3 | Mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=mayo
# Processing Record 31 of Set 3 | Chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=chuy
# Processing Record 32 of Set 3 | Shuyskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=shuyskoye
# Processing Record 33 of Set 3 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=kaitangata
# Processing Record 34 of Set 3 | Kasulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=kasulu
# Processing Record 35 of Set 3 | Jashpurnagar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=jashpurnagar
# Processing Record 36 of Set 3 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=constitucion
# Processing Record 37 of Set 3 | Pistoia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=pistoia
# Processing Record 38 of Set 3 | Sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=sinnamary
# Processing Record 39 of Set 3 | Kaoma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=kaoma
# Processing Record 40 of Set 3 | Wailuku
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=wailuku
# Processing Record 41 of Set 3 | Usinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=usinsk
# Processing Record 42 of Set 3 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=faanui
# City not found. Skipping...
# Processing Record 43 of Set 3 | Kenai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=kenai
# Processing Record 44 of Set 3 | Rantepao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=rantepao
# Processing Record 45 of Set 3 | Natal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=natal
# Processing Record 46 of Set 3 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=clyde river
# Processing Record 47 of Set 3 | Meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=meulaboh
# Processing Record 48 of Set 3 | Frederikshavn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=frederikshavn
# Processing Record 49 of Set 3 | Chute-aux-Outardes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=chute-aux-outardes
# Processing Record 50 of Set 3 | Lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=lasa
# Processing Record 1 of Set 4 | Codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=codrington
# Processing Record 2 of Set 4 | Tarko-Sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=tarko-sale
# Processing Record 3 of Set 4 | Simao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=simao
# Processing Record 4 of Set 4 | Novobirilyussy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=novobirilyussy
# Processing Record 5 of Set 4 | Panjab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=panjab
# City not found. Skipping...
# Processing Record 6 of Set 4 | Ca Mau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=ca mau
# Processing Record 7 of Set 4 | Kazanskaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=kazanskaya
# Processing Record 8 of Set 4 | Nyurba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=nyurba
# Processing Record 9 of Set 4 | Nelson Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=nelson bay
# Processing Record 10 of Set 4 | Nucet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=nucet
# Processing Record 11 of Set 4 | Anchorage
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=anchorage
# Processing Record 12 of Set 4 | Puerto Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=puerto plata
# Processing Record 13 of Set 4 | Matay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=matay
# City not found. Skipping...
# Processing Record 14 of Set 4 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=ahipara
# Processing Record 15 of Set 4 | Arrifes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=arrifes
# Processing Record 16 of Set 4 | Cabra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=cabra
# Processing Record 17 of Set 4 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=lorengau
# City not found. Skipping...
# Processing Record 18 of Set 4 | Bonavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=bonavista
# Processing Record 19 of Set 4 | Kyabram
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=kyabram
# City not found. Skipping...
# Processing Record 20 of Set 4 | College
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=college
# Processing Record 21 of Set 4 | Prescott Valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=prescott valley
# Processing Record 22 of Set 4 | Saint-Georges
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=saint-georges
# Processing Record 23 of Set 4 | Kandrian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=kandrian
# Processing Record 24 of Set 4 | Bendigo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=bendigo
# Processing Record 25 of Set 4 | Ambovombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=ambovombe
# Processing Record 26 of Set 4 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=bethel
# Processing Record 27 of Set 4 | Alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=alofi
# Processing Record 28 of Set 4 | Grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=grindavik
# City not found. Skipping...
# Processing Record 29 of Set 4 | Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=ostrovnoy
# Processing Record 30 of Set 4 | Tiznit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=tiznit
# Processing Record 31 of Set 4 | Port Macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=port macquarie
# Processing Record 32 of Set 4 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=cape town
# Processing Record 33 of Set 4 | Salinopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=salinopolis
# Processing Record 34 of Set 4 | Sao Joao da Barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=sao joao da barra
# Processing Record 35 of Set 4 | Cusuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=cusuna
# Processing Record 36 of Set 4 | Raudeberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=raudeberg
# Processing Record 37 of Set 4 | Mariinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=mariinsk
# City not found. Skipping...
# Processing Record 38 of Set 4 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=saskylakh
# City not found. Skipping...
# Processing Record 39 of Set 4 | Smirnykh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=smirnykh
# Processing Record 40 of Set 4 | Bulawayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=bulawayo
# Processing Record 41 of Set 4 | Kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=kieta
# Processing Record 42 of Set 4 | Salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=salalah
# Processing Record 43 of Set 4 | Kamakwie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=kamakwie
# Processing Record 44 of Set 4 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=east london
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 45 of Set 4 | Quatre Cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=quatre cocos
# Processing Record 46 of Set 4 | Goderich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=goderich
# Processing Record 47 of Set 4 | Khudumelapye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=khudumelapye
# Processing Record 48 of Set 4 | Pearl Lagoon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=laguna de perlas
# City not found. Skipping...
# Processing Record 49 of Set 4 | Mozarlandia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=mozarlandia
# Processing Record 50 of Set 4 | Caldwell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=caldwell
# Processing Record 1 of Set 5 | Bafoulabe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=bafoulabe
# Processing Record 2 of Set 5 | Entre Rios
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=entre rios
# Processing Record 3 of Set 5 | Canutama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=canutama
# Processing Record 4 of Set 5 | La Ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=la ronge
# City not found. Skipping...
# Processing Record 5 of Set 5 | Portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=portland
# Processing Record 6 of Set 5 | Assiniboia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=assiniboia
# Processing Record 7 of Set 5 | Huangchuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=huangchuan
# Processing Record 8 of Set 5 | Chimoio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=chimoio
# Processing Record 9 of Set 5 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=hambantota
# Processing Record 10 of Set 5 | Westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=westport
# Processing Record 11 of Set 5 | Jhabua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=jhabua
# Processing Record 12 of Set 5 | Ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=ancud
# Processing Record 13 of Set 5 | Bichena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=bichena
# Processing Record 14 of Set 5 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=bluff
# Processing Record 15 of Set 5 | Tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=tessalit
# City not found. Skipping...
# Processing Record 16 of Set 5 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=khatanga
# City not found. Skipping...
# Processing Record 17 of Set 5 | Pa Sang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=pa sang
# City not found. Skipping...
# Processing Record 18 of Set 5 | Baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=baykit
# Processing Record 19 of Set 5 | Gladstone
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=gladstone
# Processing Record 20 of Set 5 | Tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=tura
# Processing Record 21 of Set 5 | Kapuskasing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=kapuskasing
# City not found. Skipping...
# Processing Record 22 of Set 5 | Qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=qaqortoq
# City not found. Skipping...
# Processing Record 23 of Set 5 | Namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=namibe
# Processing Record 24 of Set 5 | Gorontalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=gorontalo
# Processing Record 25 of Set 5 | Maceio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=maceio
# City not found. Skipping...
# Processing Record 26 of Set 5 | Bacolod
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=bacolod
# Processing Record 27 of Set 5 | Bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=bubaque
# Processing Record 28 of Set 5 | Rensvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=rensvik
# City not found. Skipping...
# Processing Record 29 of Set 5 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=lompoc
# Processing Record 30 of Set 5 | Necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=necochea
# Processing Record 31 of Set 5 | Ulladulla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=ulladulla
# Processing Record 32 of Set 5 | Horizontina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=horizontina
# Processing Record 33 of Set 5 | Talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=talnakh
# Processing Record 34 of Set 5 | Cairns
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=cairns
# Processing Record 35 of Set 5 | Mandalgovi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=mandalgovi
# Processing Record 36 of Set 5 | General Pico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=general pico
# Processing Record 37 of Set 5 | Poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=poum
# City not found. Skipping...
# Processing Record 38 of Set 5 | Dauphin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=dauphin
# Processing Record 39 of Set 5 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=carnarvon
# Processing Record 40 of Set 5 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=butaritari
# Processing Record 41 of Set 5 | Tucumcari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=tucumcari
# City not found. Skipping...
# Processing Record 42 of Set 5 | Oktyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=oktyabrskiy
# Processing Record 43 of Set 5 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=leningradskiy
# Processing Record 44 of Set 5 | Noshiro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=noshiro
# Processing Record 45 of Set 5 | Santa Isabel do Rio Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=santa isabel do rio negro
# Processing Record 46 of Set 5 | Brigantine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=brigantine
# Processing Record 47 of Set 5 | Avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=avera
# City not found. Skipping...
# Processing Record 48 of Set 5 | Axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=axim
# Processing Record 49 of Set 5 | Walvis Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=walvis bay
# City not found. Skipping...
# Processing Record 50 of Set 5 | Hun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=hun
# Processing Record 1 of Set 6 | Hay River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=hay river
# Processing Record 2 of Set 6 | Bani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=bani
# Processing Record 3 of Set 6 | Bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=bandarbeyla
# Processing Record 4 of Set 6 | Svetlogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=svetlogorsk
# Processing Record 5 of Set 6 | Staryy Nadym
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=staryy nadym
# Processing Record 6 of Set 6 | Daru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=daru
# Processing Record 7 of Set 6 | Griffith
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=griffith
# Processing Record 8 of Set 6 | Passo de Camaragibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=passo de camaragibe
# Processing Record 9 of Set 6 | Kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=kudahuvadhoo
# Processing Record 10 of Set 6 | Nanakuli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=nanakuli
# Processing Record 11 of Set 6 | Iralaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=iralaya
# Processing Record 12 of Set 6 | Kysyl-Syr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=kysyl-syr
# Processing Record 13 of Set 6 | Intipuca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=intipuca
# Processing Record 14 of Set 6 | Souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=souillac
# Processing Record 15 of Set 6 | Marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=marawi
# Processing Record 16 of Set 6 | Bam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=bam
# Processing Record 17 of Set 6 | Juegang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=juegang
# Processing Record 18 of Set 6 | Camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=camacha
# Processing Record 19 of Set 6 | Skoghall
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=skoghall
# Processing Record 20 of Set 6 | Miri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=miri
# Processing Record 21 of Set 6 | Shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=shimoda
# Processing Record 22 of Set 6 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=narsaq
# Processing Record 23 of Set 6 | Severobaykalsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=severobaykalsk
# Processing Record 24 of Set 6 | Wainwright
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=wainwright
# Processing Record 25 of Set 6 | Kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=kununurra
# Processing Record 26 of Set 6 | Sorong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=sorong
# Processing Record 27 of Set 6 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=port lincoln
# Processing Record 28 of Set 6 | Krasnoturinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=krasnoturinsk
# Processing Record 29 of Set 6 | Port-Gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=port-gentil
# Processing Record 30 of Set 6 | Sasni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=sasni
# Processing Record 31 of Set 6 | Barmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=barmer
# Processing Record 32 of Set 6 | Luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=luanda
# Processing Record 33 of Set 6 | Andra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=andra
# Processing Record 34 of Set 6 | Akdepe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=akdepe
# Processing Record 35 of Set 6 | Hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=hamilton
# Processing Record 36 of Set 6 | Northam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=northam
# Processing Record 37 of Set 6 | Santa Cruz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=santa cruz
# Processing Record 38 of Set 6 | Sokna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=sokna
# Processing Record 39 of Set 6 | Port Hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=port hedland
# Processing Record 40 of Set 6 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=cabo san lucas
# Processing Record 41 of Set 6 | Ust-Tsilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=ust-tsilma
# Processing Record 42 of Set 6 | Sobradinho
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=sobradinho
# Processing Record 43 of Set 6 | Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=lavrentiya
# Processing Record 44 of Set 6 | Kirakira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=kirakira
# Processing Record 45 of Set 6 | Ponta Delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=ponta delgada
# Processing Record 46 of Set 6 | Nakamura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=nakamura
# Processing Record 47 of Set 6 | Sechura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=sechura
# Processing Record 48 of Set 6 | Dzerzhinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=dzerzhinsk
# Processing Record 49 of Set 6 | Shunyi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=shunyi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 50 of Set 6 | Kerouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=kerouane
# Processing Record 1 of Set 7 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=los llanos de aridane
# Processing Record 2 of Set 7 | Fukue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=fukue
# Processing Record 3 of Set 7 | Bure
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=bure
# Processing Record 4 of Set 7 | Agirish
# ...
# Processing Record 31 of Set 9 | Belomorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=belomorsk
# Processing Record 32 of Set 9 | Montorio al Vomano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=montorio al vomano
# City not found. Skipping...
# Processing Record 33 of Set 9 | Mount Isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=mount isa
# Processing Record 34 of Set 9 | Pacifica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=pacifica
# Processing Record 35 of Set 9 | Healdsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=healdsburg
# Processing Record 36 of Set 9 | Umm Lajj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=umm lajj
# Processing Record 37 of Set 9 | Clarence Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=clarence town
# Processing Record 38 of Set 9 | Shirokiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=shirokiy
# Processing Record 39 of Set 9 | Aracati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=aracati
# Processing Record 40 of Set 9 | Rio Gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=rio gallegos
# Processing Record 41 of Set 9 | Beauchamps
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=beauchamps
# Processing Record 42 of Set 9 | Ilinskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=ilinskiy
# Processing Record 43 of Set 9 | Tual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=tual
# City not found. Skipping...
# Processing Record 44 of Set 9 | Dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=dunedin
# City not found. Skipping...
# Processing Record 45 of Set 9 | Nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=nuuk
# Processing Record 46 of Set 9 | Alora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=alora
# Processing Record 47 of Set 9 | Moose Factory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=moose factory
# Processing Record 48 of Set 9 | Sampit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=sampit
# Processing Record 49 of Set 9 | Cuencame
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=cuencame
# Processing Record 50 of Set 9 | Yabrud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=yabrud
# Processing Record 1 of Set 10 | Amahai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=amahai
# Processing Record 2 of Set 10 | Ucluelet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=ucluelet
# City not found. Skipping...
# Processing Record 3 of Set 10 | Beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=beloha
# City not found. Skipping...
# Processing Record 4 of Set 10 | Youghal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=youghal
# Processing Record 5 of Set 10 | Panjakent
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=panjakent
# Processing Record 6 of Set 10 | Chernyshevsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=chernyshevsk
# Processing Record 7 of Set 10 | Nagornskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=nagornskiy
# Processing Record 8 of Set 10 | Lehigh Acres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=lehigh acres
# Processing Record 9 of Set 10 | Yantal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=yantal
# Processing Record 10 of Set 10 | Palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=palmer
# City not found. Skipping...
# Processing Record 11 of Set 10 | Phimai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=phimai
# Processing Record 12 of Set 10 | Eureka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=eureka
# Processing Record 13 of Set 10 | Mokhsogollokh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=mokhsogollokh
# Processing Record 14 of Set 10 | Jumla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=jumla
# Processing Record 15 of Set 10 | Kapit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=kapit
# Processing Record 16 of Set 10 | Talagang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=talagang
# Processing Record 17 of Set 10 | Nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=nemuro
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 18 of Set 10 | Fort Smith
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=fort smith
# Processing Record 19 of Set 10 | Povolzhskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=povolzhskiy
# Processing Record 20 of Set 10 | Nanguneri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=nanguneri
# Processing Record 21 of Set 10 | Abha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=abha
# Processing Record 22 of Set 10 | North Bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=north bend
# Processing Record 23 of Set 10 | Beyneu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=beyneu
# Processing Record 24 of Set 10 | Ukiah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=ukiah
# Processing Record 25 of Set 10 | Sergeyevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=sergeyevka
# Processing Record 26 of Set 10 | Whitehorse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=whitehorse
# City not found. Skipping...
# Processing Record 27 of Set 10 | Thunder Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=thunder bay
# City not found. Skipping...
# Processing Record 28 of Set 10 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=san patricio
# Processing Record 29 of Set 10 | Medicine Hat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=medicine hat
# Processing Record 30 of Set 10 | Son La
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=son la
# Processing Record 31 of Set 10 | Saint-Augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=saint-augustin
# Processing Record 32 of Set 10 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=kavaratti
# Processing Record 33 of Set 10 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=katsuura
# Processing Record 34 of Set 10 | West Wendover
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=west wendover
# Processing Record 35 of Set 10 | Bilibino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=bilibino
# City not found. Skipping...
# Processing Record 36 of Set 10 | Kinkala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=kinkala
# Processing Record 37 of Set 10 | Muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=muros
# Processing Record 38 of Set 10 | Atambua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=atambua
# Processing Record 39 of Set 10 | Majene
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=majene
# Processing Record 40 of Set 10 | Chongwe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=chongwe
# Processing Record 41 of Set 10 | Port Augusta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=port augusta
# Processing Record 42 of Set 10 | Conceicao da Barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=conceicao da barra
# Processing Record 43 of Set 10 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=saldanha
# Processing Record 44 of Set 10 | Grafton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=grafton
# Processing Record 45 of Set 10 | Mujiayingzi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=mujiayingzi
# Processing Record 46 of Set 10 | Tavda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=tavda
# Processing Record 47 of Set 10 | Santa Cruz del Sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=santa cruz del sur
# Processing Record 48 of Set 10 | Tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=tilichiki
# Processing Record 49 of Set 10 | Cacaotepec
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=cacaotepec
# Processing Record 50 of Set 10 | San Quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=san quintin
# Processing Record 1 of Set 11 | Ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=ixtapa
# City not found. Skipping...
# Processing Record 2 of Set 11 | Skjervoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=skjervoy
# Processing Record 3 of Set 11 | Jishou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=jishou
# Processing Record 4 of Set 11 | Yamada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=yamada
# Processing Record 5 of Set 11 | Acajutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=acajutla
# Processing Record 6 of Set 11 | Salym
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=salym
# Processing Record 7 of Set 11 | Wajir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=wajir
# Processing Record 8 of Set 11 | Okha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=okha
# Processing Record 9 of Set 11 | Oleksandrivka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=oleksandrivka
# Processing Record 10 of Set 11 | Warren
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=warren
# Processing Record 11 of Set 11 | Funadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=funadhoo
# Processing Record 12 of Set 11 | Mbandaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=mbandaka
# Processing Record 13 of Set 11 | Makakilo City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=makakilo city
# Processing Record 14 of Set 11 | Matara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=matara
# Processing Record 15 of Set 11 | Prainha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=prainha
# Processing Record 16 of Set 11 | Nargana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=nargana
# Processing Record 17 of Set 11 | Viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=viedma
# Processing Record 18 of Set 11 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=sao filipe
# Processing Record 19 of Set 11 | Mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=mitsamiouli
# Processing Record 20 of Set 11 | Wundanyi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=wundanyi
# Processing Record 21 of Set 11 | Touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=touros
# Processing Record 22 of Set 11 | Luganville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=luganville
# Processing Record 23 of Set 11 | Los Andes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=los andes
# Processing Record 24 of Set 11 | Puerto Ayacucho
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=puerto ayacucho
# Processing Record 25 of Set 11 | Chanika
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=chanika
# Processing Record 26 of Set 11 | Atasu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=atasu
# Processing Record 27 of Set 11 | Hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=hobyo
# Processing Record 28 of Set 11 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=iqaluit
# Processing Record 29 of Set 11 | Kawalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=kawalu
# Processing Record 30 of Set 11 | Santa Maria a Vico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d0947882ab92053eb516a4f607d65f7a&q=santa maria a vico
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a weather dictonary
weather_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a dataframe from weather dictionary
weather_data = pd.DataFrame(weather_dict)

# Display count
weather_data.count()
# Out:
# City          530
# Cloudiness    530
# Country       530
# Date          530
# Humidity      530
# Lat           530
# Lng           530
# Max Temp      530
# Wind Speed    530
# dtype: int64

# %%
# Export dataframe to CSV
weather_data.to_csv('weather_data.csv')

# Display dataframe
weather_data.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  San Cristobal          40      HN  1562869917        43  14.68  -86.92
# 1       Hermanus          69      ZA  1562870306        88 -34.42   19.24
# 2        Ushuaia          75      AR  1562870308        93 -54.81  -68.31
# 3         Barrow         100      AR  1562870053        59 -38.31  -60.23
# 4        Labuhan          14      ID  1562869731        96  -2.54  115.51
#
#    Max Temp  Wind Speed
# 0     86.07        8.66
# 1     57.00       13.44
# 2     37.40       18.34
# 3     58.89        0.96
# 4     71.13        1.39

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Temp.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_WindSpeed.png")

# Show plot
plt.show()
